# %% [markdown]
# # Задача:
# ДЗ - обучить при помощи tf (keras) API любое ДЗ по обучению классических моделей.
# Можно сдавать на торче.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 20)
pd.set_option('display.width', 80)

# %%
# Прочитаем файл данных
df = pd.read_csv("./winequality-white.csv", encoding='ANSI', on_bad_lines = 'skip',  sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# Разделение на признаки и целевую переменную
X = df.drop('quality', axis=1)
y = df['quality']

# %%
# Преобразование целевой переменной в one-hot encoding
from tensorflow.keras.utils import to_categorical
y = y - y.min()
num_classes = y.max() - y.min() + 1
y = to_categorical(y, num_classes=num_classes)

# %%
# Разделение данных на обучающую, тестовую и валидационную выборки
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Масштабирование данных
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dense, Dropout
# Создание модели для задачи регрессии
model = Sequential()
model.add(Dense(1400, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(140, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(num_classes, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(1))

# %%
import tensorflow as tf
# Обучение модели
opt = tf.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='mean_squared_error')
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8799 - val_loss: 0.2592
# Epoch 2/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2061 - val_loss: 0.1460
# Epoch 3/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1416 - val_loss: 0.1307
# Epoch 4/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1292 - val_loss: 0.1251
# Epoch 5/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1246 - val_loss: 0.1232
# Epoch 6/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1231 - val_loss: 0.1227
# Epoch 7/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1227 - val_loss: 0.1225
# Epoch 8/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1225 - val_loss: 0.1225
# Epoch 9/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1225 - val_loss: 0.1225
# Epoch 10/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1225 - val_loss: 0.1225

# %%
# Оценка модели на тестовых данных
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1225
# Test Loss: 0.12245023995637894

# %%
# Создание модели для задачи классификации
model_2 = Sequential()
model_2.add(Dense(4898, activation='relu', kernel_regularizer=l2(0.01)))
model_2.add(Dropout(0.2))
model_2.add(Dense(70, activation='relu', kernel_regularizer=l2(0.01)))
model_2.add(Dropout(0.2))
model_2.add(Dense(num_classes, activation='softmax'))

# %%
# Обучение модели
from tensorflow.keras.optimizers import Adam
model_2.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model_2.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5312 - loss: 1.1676 - val_accuracy: 0.5286 - val_loss: 1.1502
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5234 - loss: 1.1638 - val_accuracy: 0.5224 - val_loss: 1.1582
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5334 - loss: 1.1532 - val_accuracy: 0.5245 - val_loss: 1.1411
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5355 - loss: 1.1513 - val_accuracy: 0.5122 - val_loss: 1.1564
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5582 - loss: 1.1380 - val_accuracy: 0.5327 - val_loss: 1.1401
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5459 - loss: 1.1375 - val_accuracy: 0.5265 - val_loss: 1.1422
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5382 - loss: 1.1253 - val_accuracy: 0.5327 - val_loss: 1.1462
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5299 - loss: 1.1348 - val_accuracy: 0.5184 - val_loss: 1.1392
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5238 - loss: 1.1308 - val_accuracy: 0.5204 - val_loss: 1.1446
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5380 - loss: 1.1492 - val_accuracy: 0.5327 - val_loss: 1.1361
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5468 - loss: 1.1256 - val_accuracy: 0.5204 - val_loss: 1.1384
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5218 - loss: 1.1302 - val_accuracy: 0.5306 - val_loss: 1.1469
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5512 - loss: 1.1098 - val_accuracy: 0.5102 - val_loss: 1.1315
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5479 - loss: 1.1216 - val_accuracy: 0.5082 - val_loss: 1.1350
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5365 - loss: 1.1305 - val_accuracy: 0.5184 - val_loss: 1.1360
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5401 - loss: 1.1230 - val_accuracy: 0.5245 - val_loss: 1.1471
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5335 - loss: 1.1205 - val_accuracy: 0.5265 - val_loss: 1.1305
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5411 - loss: 1.1153 - val_accuracy: 0.5306 - val_loss: 1.1271
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5464 - loss: 1.1073 - val_accuracy: 0.5429 - val_loss: 1.1334
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5537 - loss: 1.1050 - val_accuracy: 0.5388 - val_loss: 1.1275
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5465 - loss: 1.1172 - val_accuracy: 0.5122 - val_loss: 1.1318
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5469 - loss: 1.0922 - val_accuracy: 0.5388 - val_loss: 1.1258
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5313 - loss: 1.1152 - val_accuracy: 0.5306 - val_loss: 1.1365
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5392 - loss: 1.0980 - val_accuracy: 0.5327 - val_loss: 1.1215
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5424 - loss: 1.1084 - val_accuracy: 0.5306 - val_loss: 1.1246
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5573 - loss: 1.0928 - val_accuracy: 0.5163 - val_loss: 1.1407
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5528 - loss: 1.1045 - val_accuracy: 0.5265 - val_loss: 1.1159
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5389 - loss: 1.0891 - val_accuracy: 0.5286 - val_loss: 1.1272
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5678 - loss: 1.0831 - val_accuracy: 0.5286 - val_loss: 1.1244
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5547 - loss: 1.0790 - val_accuracy: 0.5429 - val_loss: 1.1201
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5561 - loss: 1.0959 - val_accuracy: 0.5204 - val_loss: 1.1131
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5557 - loss: 1.0814 - val_accuracy: 0.5245 - val_loss: 1.1251
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5505 - loss: 1.0999 - val_accuracy: 0.5306 - val_loss: 1.1174
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5476 - loss: 1.0914 - val_accuracy: 0.5306 - val_loss: 1.1274
# Epoch 35/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5398 - loss: 1.1108 - val_accuracy: 0.5327 - val_loss: 1.1219
# Epoch 36/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5469 - loss: 1.0992 - val_accuracy: 0.5347 - val_loss: 1.1224
# Epoch 37/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5628 - loss: 1.0820 - val_accuracy: 0.5306 - val_loss: 1.1356
# Epoch 38/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5309 - loss: 1.1074 - val_accuracy: 0.5347 - val_loss: 1.1217
# Epoch 39/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5390 - loss: 1.1055 - val_accuracy: 0.5102 - val_loss: 1.1128
# Epoch 40/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5422 - loss: 1.0893 - val_accuracy: 0.5408 - val_loss: 1.1180
# Epoch 41/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5406 - loss: 1.0856 - val_accuracy: 0.5286 - val_loss: 1.1132
# Epoch 42/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5625 - loss: 1.0817 - val_accuracy: 0.5408 - val_loss: 1.1190
# Epoch 43/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5583 - loss: 1.0775 - val_accuracy: 0.5327 - val_loss: 1.1133
# Epoch 44/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5487 - loss: 1.0942 - val_accuracy: 0.5265 - val_loss: 1.1182
# Epoch 45/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5634 - loss: 1.0702 - val_accuracy: 0.5408 - val_loss: 1.1161
# Epoch 46/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5514 - loss: 1.1084 - val_accuracy: 0.5286 - val_loss: 1.1343
# Epoch 47/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5516 - loss: 1.0931 - val_accuracy: 0.5122 - val_loss: 1.1204
# Epoch 48/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5381 - loss: 1.1036 - val_accuracy: 0.5143 - val_loss: 1.1156
# Epoch 49/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5509 - loss: 1.0940 - val_accuracy: 0.5449 - val_loss: 1.1241
# Epoch 50/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5483 - loss: 1.0880 - val_accuracy: 0.5306 - val_loss: 1.1166

# %%
# Оценка модели на тестовых данных
loss, accuracy = model_2.evaluate(X_valid, y_valid)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5278 - loss: 1.1412
# Test Loss: 1.0814614295959473
# Test Accuracy: 0.5600907206535339

# %% [markdown]
# # Вывод:
# Модель регрессии дала результат Test Loss: 0.12245023995637894, что является достаточно хорошим показателем при у = 0...6.
# Модель классификации: Test Loss: 1.0814614295959473
# Test Accuracy: 0.5600907206535339, что означает угадывание класса в 56% тестовых данных.
